# %% [markdown]
# # Read data

# %%
import pandas as pd

df = pd.read_csv('data1.csv')
df.head()
# Out:
#   Date;Berri 1;C'te-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain
# 0                    01/01/2012;35;0;38;51;26;10;16;
# 1                    02/01/2012;83;1;68;153;53;6;43;
# 2                  03/01/2012;135;2;104;248;89;3;58;
# 3                 04/01/2012;144;1;116;318;111;8;61;
# 4                 05/01/2012;197;2;124;330;97;13;95;

# %%
df = pd.read_csv('data1.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
df.head()
# Out:
#             Berri 1  C'te-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  \
# Date
# 2012-01-01       35                      0             38             51
# 2012-01-02       83                      1             68            153
# 2012-01-03      135                      2            104            248
# 2012-01-04      144                      1            116            318
# 2012-01-05      197                      2            124            330
#
#             du Parc  Pierre-Dupuy  Rachel1  St-Urbain
# Date
# 2012-01-01       26            10       16        NaN
# 2012-01-02       53             6       43        NaN
# 2012-01-03       89             3       58        NaN
# 2012-01-04      111             8       61        NaN
# 2012-01-05       97            13       95        NaN

# %% [markdown]
# ### N/A values at read

# %%
df = pd.read_csv('data2.csv')
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26532099  10/22/2013 11:55:50 AM                     NaN    TLC
#
#                        Agency Name              Complaint Type  \
# 0  New York City Police Department                         NaN
# 1  New York City Police Department             Illegal Parking
# 2  New York City Police Department          Noise - Commercial
# 3  New York City Police Department             Noise - Vehicle
# 4    Taxi and Limousine Commission  For Hire Vehicle Complaint
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# ...

# %%
na_values = ['NO CLUE', 'N/A', '0']
df = pd.read_csv('data2.csv', na_values=na_values, dtype={'Incident Zip': str})
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26532099  10/22/2013 11:55:50 AM                     NaN    TLC
#
#                        Agency Name              Complaint Type  \
# 0  New York City Police Department                         NaN
# 1  New York City Police Department             Illegal Parking
# 2  New York City Police Department          Noise - Commercial
# 3  New York City Police Department             Noise - Vehicle
# 4    Taxi and Limousine Commission  For Hire Vehicle Complaint
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# ...
