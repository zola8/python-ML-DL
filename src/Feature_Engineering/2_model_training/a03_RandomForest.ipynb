# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv('../../data/housing_prices_train.csv')

features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X_train, X_test, y_train, y_test = train_test_split(df[features], df.SalePrice, random_state=42)

X_train[:3]
# Out:
#       LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 1023     3182       2005      1504         0         2             2
# 810     10140       1974      1309         0         1             3
# 1384     9060       1939       698       560         1             2
#
#       TotRmsAbvGrd
# 1023             7
# 810              5
# 1384             6

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
print("Validation MAE: {:,.0f}".format(mae))

mse = mean_squared_error(y_test, y_pred)
print("Validation MSE: {:,.0f}".format(mse))

r2 = r2_score(y_test, y_pred)
print("Validation R2: {:,.0f}".format(r2))
# Out:
# Validation MAE: 21,599
# Validation MSE: 1,027,521,256
# Validation R2: 1

# %%
# just for comparing, let's see a DecisionTree model
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
print("Validation MAE: {:,.0f}".format(mae))
# Out:
# Validation MAE: 30,161
