# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=100, random_state=42)

df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df['Target'] = y

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Feature 1", y="Feature 2", hue="Target", palette="Set1")
plt.title("2D Classification Data (make_moons)")
plt.grid(True)
plt.show()

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Create synthetic 2D data
X, y = make_moons(n_samples=300, noise=0.3, random_state=42)

# Create a DataFrame for plotting
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df['Target'] = y

df.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   0.924865  -0.237611       1
# 1   2.587875  -0.112862       1
# 2  -0.421033   0.447485       1
# 3   0.693145   0.481778       0
# 4   1.190855  -0.525165       1

# %%
# Visualize the 2D data
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Feature 1", y="Feature 2", hue="Target", palette="Set1")
plt.title("2D Classification Data (make_moons) with noise")
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
df = pd.DataFrame(X_scaled, columns=["Feature 1", "Feature 2"])
df['Target'] = y
df.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   0.456321  -0.880218       1
# 1   2.252926  -0.663544       1
# 2  -0.997697   0.309701       1
# 3   0.205986   0.369263       0
# 4   0.743678  -1.379659       1

# %%
# Visualize the 2D data
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Feature 1", y="Feature 2", hue="Target", palette="Set1")
plt.title("2D Classification Data (make_moons) with noise")
plt.grid(True)
plt.show()

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.3, random_state=42, stratify=y
)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Train a k-NN classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

# Predict and evaluate
y_pred = knn.predict(X_test)
print(f"Test Accuracy (k=5): {accuracy_score(y_test, y_pred):.2f}")
# Out:
# Test Accuracy (k=5): 0.87

# %%
df1 = pd.DataFrame(X_train, columns=["Feature 1", "Feature 2"])
df1['Target'] = y_train

df_pred = pd.DataFrame(X_test, columns=["Feature 1", "Feature 2"])
df_pred['Target'] = y_pred

# Visualize the 2D data
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df1, x="Feature 1", y="Feature 2", hue="Target", palette="Set1")
sns.scatterplot(data=df_pred, x="Feature 1", y="Feature 2", hue="Target", palette="Set2")
plt.title("KNN Prediction")
plt.grid(True)
plt.show()
