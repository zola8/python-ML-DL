# %% [markdown]
# # Mode, Median, Mean
#
# ![image](mode_median_mean.png)

# %%
import pandas as pd

arr = [25, 12, 5, 24, 15, 22, 23, 25]
data = pd.Series(arr)

# %%
print('Mean:', data.mean())
print('Median:', data.median())
print('Mode:', data.mode()[0])
# Out:
# Mean: 18.875
# Median: 22.5
# Mode: 25

# %%
arr.sort()
arr
# Out:
# [5, 12, 15, 22, 23, 24, 25, 25]
